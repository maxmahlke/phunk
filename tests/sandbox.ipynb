# %%
# import numpy as np
import pandas as pd
import phunk

# %% [markdown]
# # minimalistic: does phunk run?

# %%
# Observations from Gehrels 1956
PHASE = [0.57, 1.09, 3.20, 10.99, 14.69, 20.42]
MAG = [6.555, 6.646, 6.793, 7.130, 7.210, 7.414]

phase = PHASE
mag = MAG

pc = phunk.PhaseCurve(phase=phase, mag=mag)
pc.fit(models=["HG1G2"])

pc.HG1G2.H, pc.HG1G2.G1, pc.HG1G2.G2

# %% [markdown]
# # SOCCA

# %%
data = pd.read_csv("data/Eugenia_ztf.csv")
cols = ["Date", "cmagpsf"]

sol = pd.read_csv("data/Eugenia_socca.csv")

# %%
data.columns[data.columns.str.contains("f")]

# %%
pc = phunk.PhaseCurve(
    target="Eugenia",
    epoch=data["Date"].values,
    phase=data["Phase"].values,
    mag=data["cmred"].values,
    band=data["cfid"].values,
)

# %%
pc.get_ephems()

# %%
pc.fit(models=["HG1G2"])
pc.HG1G2.H1, pc.HG1G2.H2

# %%
import numpy as np

t0 = data["Date"].values.mean()
p0 = {
    "H": sol["H_1"].values[0],
    "G1": sol["G1_1"].values[0],
    "G2": sol["G2_1"].values[0],
    "period": sol["period"].values[0],
    "alpha": sol["alpha0"].values[0],
    "delta": sol["delta0"].values[0],
    "a_b": sol["a_b"].values[0],
    "a_c": sol["a_c"].values[0],
    "W0": np.rad2deg(
        sol["phi0"].values[0]
    ),  # but this is in fact W0, not phi0 as in SEP long.
    "t0": t0,
}
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 3
#       1 import numpy as np
# ----> 3 t0 = data["Date"].values.mean()
#       4 p0 = {
#       5     "H": sol["H_1"].values[0],
#       6     "G1": sol["G1_1"].values[0],
#    (...)
#      16     "t0": t0,
#      17 }
#
# NameError: name 'data' is not defined

# %%
pc.fit(models=["sHG1G2"])

# %%
pc.fit(models=["SOCCA"], p0=p0, remap=True)
pc.SOCCA.period
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 pc.fit(models=["SOCCA"], p0=p0, remap=True)
#       2 pc.SOCCA.period
#
# NameError: name 'pc' is not defined

# %%
import numpy as np
import pandas as pd
import phunk

data = pd.read_csv("data/Eugenia_ztf.csv")
cols = ["Date", "cmagpsf"]

sol = pd.read_csv("data/Eugenia_socca.csv")

t0 = data["Date"].values.mean()
p0 = {
    "H1": sol["H_1"].values[0],
    "H2": sol["H_2"].values[0],
    "G11": sol["G1_1"].values[0],
    "G12": sol["G1_2"].values[0],
    "G21": sol["G2_1"].values[0],
    "G22": sol["G2_2"].values[0],
    "period": sol["period"].values[0],
    "alpha": sol["alpha0"].values[0],
    "delta": sol["delta0"].values[0],
    "a_b": sol["a_b"].values[0],
    "a_c": sol["a_c"].values[0],
    "W0": np.rad2deg(
        sol["phi0"].values[0]
    ),  # but this is in fact W0, not phi0 as in SEP long.
    "t0": t0,
}

# %%
pc = phunk.PhaseCurve(
    target="Eugenia",
    epoch=data["Date"].values,
    phase=data["Phase"].values,
    mag=data["cmred"].values,
    band=data["cfid"].values,
)

# %%
pc.fit(models=["SOCCA"], p0=p0, remap=True)
# Out:
# No RA or Dec provided but epoch and target found.
# Querying ephemerides via IMCCE Miriade..
# {'X': np.float64(0.06669611373299808), 'Y': np.float64(0.06396603936379161), 'Z': np.float64(0.18042094803581585), 'period': np.float64(8.19660207670796e-07), 'u_a_b': np.float64(0.1723773059151953), 'u_a_c': np.float64(0.44446109666295136), 'u_W0': np.float64(0.11071861447727696), 'H1': np.float64(0.5082255936695926), 'u_G11': np.float64(1.335769798193411), 'u_G21': np.float64(1.8253294366163306), 'H2': np.float64(2.8751799000656075), 'u_G12': np.float64(6.302395308189066), 'u_G22': np.float64(9.148174987323127), 't0': np.float64(0.0)}

# %%
# pc.SOCCA
# Out:
# np.float64(0.6200258341000104)

# %%
pc.SOCCA.W0
# Out:
# np.float64(-32.70762223624669)

# %%
sol["H_2"]
# Out:
# 0    7.571619
# Name: H_2, dtype: float64
