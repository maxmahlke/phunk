# %%
# import numpy as np
import pandas as pd
import phunk

# %% [markdown]
# # minimalistic: does phunk run?

# %%
# Observations from Gehrels 1956
PHASE = [0.57, 1.09, 3.20, 10.99, 14.69, 20.42]
MAG = [6.555, 6.646, 6.793, 7.130, 7.210, 7.414]

phase = PHASE
mag = MAG

pc = phunk.PhaseCurve(phase=phase, mag=mag)
pc.fit(models=['HG1G2'])

pc.HG1G2.H, pc.HG1G2.G1, pc.HG1G2.G2
# Out:
# (6.435448785088962, 0.3182500366268652, 0.3436377645870534)

# %% [markdown]
# # SOCCA

# %%
data = pd.read_csv('data/Eugenia_ztf.csv')
cols = ['Date','cmagpsf']

sol =  pd.read_csv('data/Eugenia_socca.csv')

# %%
data.columns[ data.columns.str.contains('f') ]
# Out:
# Index(['d:from_upper', 'd:jd_first_real_det', 'd:lc_features_g',
#        'd:lc_features_r', 'd:rf_kn_vs_nonkn', 'd:rf_snia_vs_nonia', 'i:chipsf',
#        'i:diffmaglim', 'cfid', 'i:field', 'i:isdiffpos', 'cmagpsf',
#        'csigmapsf', 'i:tooflag', 'v:classification', 'v:firstdate',
#        'i:magpsf_red'],
#       dtype='str')

# %%
pc = phunk.PhaseCurve(
    target="Eugenia",
    epoch=data["Date"].values - 2400000.5,
    phase=data["Phase"].values,
    mag=data["cmagpsf"].values,
    band=data["cfid"].values,
)

# %%
pc.get_ephems()
# Out:
# Querying ephemerides via IMCCE Miriade..

# %%
pc.fit(models=['HG1G2'])
pc.HG1G2.H1, pc.HG1G2.H2
# Out:
# (10.908107493146632, 11.49874075800082)

# %%
m = 'HG1G2'
pc.HG1G2

# %%
setattr( getattr( pc, m), 'H1', -1 )

# %%
pc.HG1G2.H1, pc.HG1G2.H2
# Out:
# (-1, 11.49874075800082)

# %%
pc.fit(models=['SOCCA'], p0='toto')
# Out:
# SOCCA
#
# toto
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[12], line 1
# ----> 1 pc.fit(models=['SOCCA'], p0='toto')
#
# File ~/Documents/softs/phunk-fork/phunk/core.py:98, in PhaseCurve.fit(self, models, p0)
#      91     setattr(
#      92         self,
#      93         model,
#      94         getattr(phunk.models, model)(bands=set(self.band)),
#      95     )
#      97 if getattr(self, model).is_fittable(self):
# ---> 98     getattr(self, model).fit(self)
#
# File ~/Documents/softs/phunk-fork/phunk/models.py:767, in SOCCA.fit(self, pc, weights, constrain_g1g2)
#     764 if weights is None:
#     765     weights = np.ones(pc.mag.shape)
# --> 767 out = lmfit.minimize(
#     768     residual,
#     769     params,
#     770     args=(
#     771         np.radians(pc.phase),
#     772         pc.mag,
#     773         weights,
#     774         pc.band,
#     775         np.radians(pc.ra),
#     776         np.radians(pc.dec),
#     777     ),
#     778     method="least_squares",
#     779     jac="2-point",
#     780     loss="soft_l1",
#     781 )
#     783 for name, param in out.params.items():
#     784     if name in ["alpha", "delta", "W0"]:
#
# File ~/anaconda3/envs/dev_phunk/lib/python3.11/site-packages/lmfit/minimizer.py:2616, in minimize(fcn, params, method, args, kws, iter_cb, scale_covar, nan_policy, reduce_fcn, calc_covar, max_nfev, **fit_kws)
#    2476 """Perform the minimization of the objective function.
#    2477
#    2478 The minimize function takes an objective function to be minimized,
#    (...)   2610
#    2611 """
#    2612 fitter = Minimizer(fcn, params, fcn_args=args, fcn_kws=kws,
#    2613                    iter_cb=iter_cb, scale_covar=scale_covar,
#    2614                    nan_policy=nan_policy, reduce_fcn=reduce_fcn,
#    2615                    calc_covar=calc_covar, max_nfev=max_nfev, **fit_kws)
# -> 2616 return fitter.minimize(method=method)
#
# File ~/anaconda3/envs/dev_phunk/lib/python3.11/site-packages/lmfit/minimizer.py:2355, in Minimizer.minimize(self, method, params, **kws)
#    2352         if (key.lower().startswith(user_method) or
#    2353                 val.lower().startswith(user_method)):
#    2354             kwargs['method'] = val
# -> 2355 return function(**kwargs)
#
# File ~/anaconda3/envs/dev_phunk/lib/python3.11/site-packages/lmfit/minimizer.py:1564, in Minimizer.least_squares(self, params, max_nfev, **kws)
#    1561 result.call_kws = least_squares_kws
#    1563 try:
# -> 1564     ret = least_squares(self.__residual, start_vals,
#    1565                         bounds=(lower_bounds, upper_bounds),
#    1566                         **least_squares_kws)
#    1567     result.residual = ret.fun
#    1568 except AbortFitException:
#
# File ~/anaconda3/envs/dev_phunk/lib/python3.11/site-packages/scipy/_lib/_util.py:717, in _workers_wrapper.<locals>.inner(*args, **kwds)
#     715 with MapWrapper(_workers) as mf:
#     716     kwargs['workers'] = mf
# --> 717     return func(*args, **kwargs)
#
# File ~/anaconda3/envs/dev_phunk/lib/python3.11/site-packages/scipy/optimize/_lsq/least_squares.py:901, in least_squares(fun, x0, jac, bounds, method, ftol, xtol, gtol, x_scale, loss, f_scale, diff_step, tr_solver, tr_options, jac_sparsity, max_nfev, verbose, args, kwargs, callback, workers)
#     897     raise ValueError("Each lower bound must be strictly less than each "
#     898                      "upper bound.")
#     900 if not in_bounds(x0, lb, ub):
# --> 901     raise ValueError("Initial guess is outside of provided bounds")
#     903 x_scale = check_x_scale(x_scale, x0, method)
#     905 ftol, xtol, gtol = check_tolerance(ftol, xtol, gtol, method)
#
# ValueError: Initial guess is outside of provided bounds

# %%
setattr(pc, 'SOCCA', getattr(phunk.models, 'SOCCA')(pinit='toto'))

# %%
pc.HG1G2.NAME
pc.HG1G2.NAME
pc.SOCCA.NAME
# pc.SOCCA.pinit
# getattr(phunk.models, 'SOCCA')

# %%
p0 = {
    "H": sol.loc[0, "H_1"],
    "G1": sol.loc[0, "G1_1"],
    "G2": sol.loc[0, "G2_1"],
    "period": sol.loc[0, "period"],
    "alpha": sol.loc[0, "alpha0"],
    "delta": sol.loc[0, "delta0"],
    "a_b": sol.loc[0, "a_b"],
    "a_c": sol.loc[0, "a_c"],
    "W0": sol.loc[0, "phi0"],
    "t0": 2459580.5,
}

# %%
for k,v in p0.items():
    print(k)

# %%
pc.SOCCA.H = sol.loc[0, "H_1"]
pc.SOCCA.G1 = sol.loc[0, "G1_1"]
pc.SOCCA.G2 = sol.loc[0, "G2_1"]
pc.SOCCA.period = sol.loc[0, "period"]
pc.SOCCA.alpha = sol.loc[0, "alpha0"]
pc.SOCCA.delta = sol.loc[0, "delta0"]
pc.SOCCA.a_b = sol.loc[0, "a_b"]
pc.SOCCA.a_c = sol.loc[0, "a_c"]
pc.SOCCA.t0 = 2459580.5 # Hard coded in fink utils
pc.SOCCA.W0 = sol.loc[0, "phi0"]

# %%
pc.fit()

# %%
pc.SOCCA.H

# %%
sol.columns
